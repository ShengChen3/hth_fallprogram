# %%
# sort seasons list to increase frames usability

import pandas

pandas.options.display.max_columns = None
pandas.options.display.max_rows = None

baseball_data = pandas.read_csv("baseballdata.csv")

teams = baseball_data["current"].unique()
teams
# Out:
# array(['Arizona Diamondbacks', 'Atlanta Braves', 'Baltimore Orioles',
#        'Boston Red Sox', 'Chicago Cubs', 'Chicago White Sox',
#        'Cincinnati Reds', 'Cleveland Indians', 'Colorado Rockies',
#        'Detroit Tigers', 'Houston Astros', 'Kansas City Royals',
#        'Los Angeles Angels of Anaheim', 'Los Angeles Dodgers',
#        'Miami Marlins', 'Milwaukee Brewers', 'Minnesota Twins',
#        'New York Mets', 'New York Yankees', 'Oakland Athletics',
#        'Philadelphia Phillies', 'Pittsburgh Pirates', 'San Diego Padres',
#        'San Francisco Giants', 'Seattle Mariners', 'St. Louis Cardinals',
#        'Tampa Bay Rays', 'Texas Rangers', 'Toronto Blue Jays',
#        'Washington Nationals'], dtype=object)

# %%
AD = baseball_data[ baseball_data["current"] == 'Arizona Diamondbacks']
RunsAD = AD["R"].mean()
RunsAD

AB = baseball_data[ baseball_data["current"] == 'Atlanta Braves']
RunsAB = AB["R"].mean()
RunsAB

BO = baseball_data[ baseball_data["current"] == 'Baltimore Orioles']
RunsBO = BO["R"].mean()
RunsBO

BRS = baseball_data[ baseball_data["current"] == 'Boston Red Sox']
RunsBRS = BRS["R"].mean()
RunsBRS

CC = baseball_data[ baseball_data["current"] == 'Chicago Cubs']
RunsCC = CC["R"].mean()
RunsCC

CWS = baseball_data[ baseball_data["current"] == 'Chicago White Sox']
RunsCWS = CWS["R"].mean()
RunsCWS

CR = baseball_data[ baseball_data["current"] == 'Cincinnati Reds']
RunsCR = CR["R"].mean()
RunsCR

CI = baseball_data[ baseball_data["current"] == 'Cleveland Indians']
RunsCI = CI["R"].mean()
RunsCI

CRookies = baseball_data[ baseball_data["current"] == 'Colorado Rockies']
RunsCRookies = CRookies["R"].mean()
RunsCRookies

DT = baseball_data[ baseball_data["current"] == 'Detroit Tigers']
RunsDT = DT["R"].mean()
RunsDT

HA = baseball_data[ baseball_data["current"] == 'Houston Astros']
RunsHA = HA["R"].mean()
RunsHA

LAAA = baseball_data[ baseball_data["current"] == 'Los Angeles Angels of Anaheim']
RunsLAAA = LAAA["R"].mean()
RunsLAAA

LAD = baseball_data[ baseball_data["current"] == 'Los Angeles Dodgers']
RunsLAD = LAD["R"].mean()
RunsLAD

MM = baseball_data[ baseball_data["current"] == 'Miami Marlins']
RunsMM = MM["R"].mean()
RunsMM

MB = baseball_data[ baseball_data["current"] == 'Milwaukee Brewers']
RunsMB = MB["R"].mean()
RunsMB

NYM = baseball_data[ baseball_data["current"] == 'New York Mets']
RunsNYM = NYM["R"].mean()
RunsNYM

NYY = baseball_data[ baseball_data["current"] == 'New York Yankees']
RunsNYY = NYY["R"].mean()
RunsNYY

OA = baseball_data[ baseball_data["current"] == 'Oakland Athletics']
RunsOA = OA["R"].mean()
RunsOA

PPhillies = baseball_data[ baseball_data["current"] == 'Philadelphia Phillies']
RunsPPhillies = PPhillies["R"].mean()
RunsPPhillies

PPirates = baseball_data[ baseball_data["current"] == 'Pittsburgh Pirates']
RunsPPirates = PPirates["R"].mean()
RunsPPirates

SDP = baseball_data[ baseball_data["current"] == 'San Diego Padres']
RunsSDP = SDP["R"].mean()
RunsSDP

SFG = baseball_data[ baseball_data["current"] == 'San Francisco Giants']
RunsSFG = SFG["R"].mean()
RunsSFG

SM = baseball_data[ baseball_data["current"] == 'Seattle Mariners']
RunsSM = SM["R"].mean()
RunsSM

SLC = baseball_data[ baseball_data["current"] == 'St. Louis Cardinals']
RunsSLC = SLC["R"].mean()
RunsSLC

TBR = baseball_data[ baseball_data["current"] == 'Tampa Bay Rays']
RunsTBR = TBR["R"].mean()
RunsTBR

TR = baseball_data[ baseball_data["current"] == 'Texas Rangers']
RunsTR = TR["R"].mean()
RunsTR

TBJ = baseball_data[ baseball_data["current"] == 'Toronto Blue Jays']
RunsTBJ = TBJ["R"].mean()
RunsTBJ

WN = baseball_data[ baseball_data["current"] == 'Washington Nationals']
RunsWN = WN["R"].mean()
RunsWN
  
totals = []

totals.append(RunsAD)
    
RunsAD, RunsAB, RunsBO, RunsBRS, RunsCC, RunsCWS, RunsCR, RunsCI, RunsCRookies, RunsDT, RunsHA, RunsLAAA, RunsLAD, RunsMM, RunsMB, RunsNYM, RunsNYY, RunsOA, RunsPPhillies, RunsPPirates, RunsSDP, RunsSFG, RunsSM, RunsSLC, RunsTBR, RunsTR, RunsTBJ, RunsWN
# Out:
# (731.8421052631579,
#  662.418439716312,
#  673.5086206896551,
#  725.8620689655172,
#  686.886524822695,
#  680.3103448275862,
#  686.5925925925926,
#  705.9741379310345,
#  806.5416666666666,
#  723.8706896551724,
#  663.7636363636364,
#  690.5357142857143,
#  687.3308270676691,
#  680.625,
#  704.8958333333334,
#  649.9090909090909,
#  757.7894736842105,
#  688.698275862069,
#  676.179104477612,
#  682.4148148148148,
#  639.0,
#  711.5522388059702,
#  706.45,
#  701.6444444444444,
#  712.1578947368421,
#  716.8571428571429,
#  736.775,
#  657.8541666666666)

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
display(HTML("<style>.output_result { max-width:100% !important; }</style>"))
display(HTML("<style>.prompt { display:none !important; }</style>"))
