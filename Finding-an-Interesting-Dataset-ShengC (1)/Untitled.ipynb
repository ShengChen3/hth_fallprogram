# %%
# sort seasons list to increase frames usability

import pandas

pandas.options.display.max_columns = None
pandas.options.display.max_rows = None

baseball_data = pandas.read_csv("baseballdata.csv")

Years = list(baseball_data["Year"].unique())
Years.sort()
frames = []

for Years in Year:
    tm_data = baseball_data[ baseball_data["Year"] == Years]
    frames.append(tm_data)
    
last_year = frames[0]
first_year = frames[-1]

ratios = []

baseball_data

# last_year
#for index, row in last_year.iterrows():
#    if row["G"] != 0:
#        ratios.append(row["Lg"] / row["G"])
#    else: 
#        ratios.append(row["Lg"] / 1)
    
#last_year["RATIOS"] = ratios


big_wins = last_year[ (last_year["W"] > 80)]

big_wins
# Out:
#       Unnamed: 0  Rk  Year                    Tm          Lg    G    W   L  \
# 160          161   1  2016     Baltimore Orioles     AL East  162   89  73
# 276          277   1  2016        Boston Red Sox     AL East  162   93  69
# 392          393   1  2016          Chicago Cubs  NL Central  162  103  58
# 784          785   1  2016     Cleveland Indians  AL Central  161   94  67
# 924          925   1  2016        Detroit Tigers  AL Central  161   86  75
# 1040        1041   1  2016        Houston Astros     AL West  162   84  78
# 1095        1096   1  2016    Kansas City Royals  AL Central  162   81  81
# 1199        1200   1  2016   Los Angeles Dodgers     NL West  162   91  71
# 1520        1521   1  2016         New York Mets     NL East  162   87  75
# 1575        1576   1  2016      New York Yankees     AL East  162   84  78
# 2122        2123   1  2016  San Francisco Giants     NL West  162   87  75
# ...
